# %%
import random
import os
import re
from glob import glob
from tqdm import tqdm
import numpy as np

import pandas as pd
import ast
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from PIL import Image, ImageDraw, _imaging
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Activation
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras import metrics
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
from sklearn.model_selection import train_test_split
import tensorflow as tf
from datetime import datetime
from keras.callbacks import History, ModelCheckpoint
history = History()
# Out:
# <style>.container { width:100% !important; }</style>

# %%
def generateTrainData(recordsPerTrainClass, output_height, output_width):

    test_df = pd.read_csv('test_simplified.csv')

    # Get names of all train csv files with the pattern match below
    fnames = glob('train_simplified/*.csv')

    rows = recordsPerTrainClass
    # Get n rows from all the csv files and append them into one dataframe
    train_df = pd.DataFrame(columns=pd.read_csv(fnames[0], nrows=1).columns)
    for name in fnames:
        data = pd.read_csv(name, nrows=recordsPerTrainClass)
        train_df = train_df.append(data)
    train_df = train_df.reset_index().drop('index', axis=1)
    # Get only those which were correctly recognized
    train_df = train_df[train_df['recognized'] == True]
    
    # Convert the drawing column to matrix
    train_df['drawing'] = train_df['drawing'].apply(ast.literal_eval)
    test_df['drawing'] = test_df['drawing'].apply(ast.literal_eval)

    # Convert drawing to images
    train_df['img'] = train_df['drawing'].apply(lambda x: draw_it(x, output_height, output_width))
    test_df['img'] = test_df['drawing'].apply(lambda x: draw_it(x, output_height, output_width))
    # train_df['img'] = train_df[['drawing']].apply(lambda x: draw_it(x['drawing'], output_height, output_width), axis=1)
    # test_df['img'] = test_df[['drawing']].apply(lambda x: draw_it(x['drawing'], output_height, output_width), axis=1)
    
    return train_df, test_df
    
def showSampleImgs():
    n_samp = 3
    train_df_sample = train_df.sample(n_samp)
    plt.figure(figsize=(4,4))
    for i in range(n_samp):
        draw = train_df_sample.iloc[i]['drawing']
        label = train_df_sample.iloc[i]['word']
        plt.subplot(n_samp,1,i+1)
        for stroke in draw:
            plt.plot(stroke[0], stroke[1], marker='.', color='black')
            plt.title(label)
            plt.axis('off')
    plt.show()    
    
# Convert drawings to images
def draw_it(raw_strokes, output_height, output_width):
    image = Image.new("P", (255,255)
#                       , color=1
            )
    image_draw = ImageDraw.Draw(image)

    for stroke in raw_strokes:
        for i in range(len(stroke[0])-1):

            image_draw.line([stroke[0][i], 
                             stroke[1][i],
                             stroke[0][i+1], 
                             stroke[1][i+1]],
                            fill=255, width=6)
    # Reduce image size
    image = image.resize((output_height,output_width),Image.ANTIALIAS)
    
    return np.array(image)

# Show an image from the dataframe
def showImgFromDf(df, index):
    # Show an image
    plt.imshow(df.iloc[index]['img'],cmap='gray')
    plt.title(df.iloc[index]['word'])
    plt.show()
    
def CNN_dataPrep(train_df, img_height, img_width):
    
    num_classes = train_df['word'].nunique()
    # Data Preprocessing

    # Shuffle the data
    random.seed(111)
    train_df = train_df.sample(train_df.shape[0])
    
    # input image dimensions
    img_rows, img_cols = img_height, img_width
    input_shape = (img_rows, img_cols)
    
    # Reshape the array
    imgArr = np.vstack(train_df['img'].values).flatten().reshape((train_df['img'].shape[0], img_rows, img_cols))
    imgArr_test = np.vstack(test_df['img'].values).flatten().reshape((test_df['img'].shape[0], img_rows, img_cols))
    
    # In Keras, the layers used for two-dimensional convolutions expect pixel values with the dimensions [width][height][pixels] for TF.
    # In the case of RGB, the first dimension pixels would be 3 for the red, green and blue components and it would be like having 3 image inputs for every color image. In this case, the pixel values are gray scale, the pixel dimension is set to 1.
    imgArr = imgArr.reshape(imgArr.shape[0], img_rows, img_cols, 1).astype('float32')
    imgArr_test = imgArr_test.reshape(imgArr_test.shape[0], img_rows, img_cols, 1).astype('float32')
    
    # Initialize the y_train
    y_train = train_df['word']
    
    # Convert class labels from categorical to numerical
    unique_classes_list = y_train.unique()
    map_class_to_numeric = {k: v for v, k in enumerate(y_train.unique())}
    map_numeric_to_class = {v: k for k, v in map_class_to_numeric.iteritems()}
    y_train_numeric = y_train.apply(lambda x: map_class_to_numeric[x])

    # convert class vectors to binary class matrices
    y_train_one_hot = keras.utils.to_categorical(y_train_numeric, num_classes)
    num_classes = y_train_one_hot.shape[1]
    
    X_train, X_test, y_train, y_test = train_test_split(imgArr, y_train_one_hot, test_size=0.2)
    
    return X_train, X_test, y_train, y_test, imgArr_test, map_class_to_numeric, map_numeric_to_class
    
    
def top_3_accuracy(y_true, y_pred):
    return metrics.top_k_categorical_accuracy(y_true, y_pred, k=3)


def baseline_conv_model(num_filters, num_classes, img_rows, img_cols):
    model = Sequential()
    model.add(Conv2D(num_filters, (5,5), input_shape=(img_rows,img_cols,1), activation='relu')) 
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.2))
    model.add(Conv2D(num_filters*2, (5,5), input_shape=(img_rows,img_cols,1), activation='relu')) 
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.2))
    model.add(Conv2D(num_filters*2, (3,3), input_shape=(img_rows,img_cols,1), activation='relu')) 
    # model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.2))
    model.add(Flatten())
    model.add(Dense(1000, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(500, activation='relu'))
    model.add(Dropout(0.2))
#     model.add(Dense(num_classes, activation='softmax'))
    model.add(Dense(units=num_classes))
#     model.add(Activation('softmax'))
    model.add(Activation(tf.nn.softmax))

    # Compile
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', top_3_accuracy, 'categorical_crossentropy'])
    # checkpoint
    filepath="weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    return model

# %%
recordsPerTrainClass = 2000
img_height = img_width = 64

# Get data and transform drawing into image
train_df, test_df = generateTrainData(recordsPerTrainClass, img_height, img_width)

# Transform data for CNN
X_train, X_test, y_train, y_test, imgArr_test, map_class_to_numeric, map_numeric_to_class = CNN_dataPrep(train_df, img_height, img_width)

# %%
num_filters = 8
num_classes = train_df['word'].nunique()
model = baseline_conv_model(num_filters, num_classes, img_height, img_width)
print(model.summary())

hist = model.fit(X_train, 
          y_train, 
          validation_data=(X_test, y_test),
          epochs=100, 
          batch_size=5000, 
          verbose=2,
          callbacks=[history, checkpoint])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 60, 60, 8)         208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 8)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30, 8)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 26, 26, 16)        3216
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 16)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 13, 13, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 11, 16)        2320
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 11, 11, 16)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1936)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              1937000
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 500)               500500
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 340)               170340
# _________________________________________________________________
# activation_1 (Activation)    (None, 340)               0
# =================================================================
# Total params: 2,613,584
# Trainable params: 2,613,584
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 499272 samples, validate on 124819 samples
# Epoch 1/100
#  - 1133s - loss: 6.9346 - acc: 0.0050 - top_3_accuracy: 0.0138 - categorical_crossentropy: 6.9346 - val_loss: 5.6495 - val_acc: 0.0109 - val_top_3_accuracy: 0.0304 - val_categorical_crossentropy: 5.6495
# Epoch 2/100
#  - 1085s - loss: 4.9997 - acc: 0.0486 - top_3_accuracy: 0.1081 - categorical_crossentropy: 4.9997 - val_loss: 4.0297 - val_acc: 0.1653 - val_top_3_accuracy: 0.3076 - val_categorical_crossentropy: 4.0297
# Epoch 3/100
#  - 1090s - loss: 3.8357 - acc: 0.1767 - top_3_accuracy: 0.3296 - categorical_crossentropy: 3.8357 - val_loss: 3.0965 - val_acc: 0.3111 - val_top_3_accuracy: 0.5093 - val_categorical_crossentropy: 3.0965
# Epoch 4/100
#  - 1093s - loss: 3.2028 - acc: 0.2739 - top_3_accuracy: 0.4654 - categorical_crossentropy: 3.2028 - val_loss: 2.6662 - val_acc: 0.3837 - val_top_3_accuracy: 0.5915 - val_categorical_crossentropy: 2.6662
# Epoch 5/100
#  - 1085s - loss: 2.8426 - acc: 0.3336 - top_3_accuracy: 0.5395 - categorical_crossentropy: 2.8426 - val_loss: 2.3782 - val_acc: 0.4339 - val_top_3_accuracy: 0.6487 - val_categorical_crossentropy: 2.3782
# Epoch 6/100
#  - 1089s - loss: 2.6111 - acc: 0.3735 - top_3_accuracy: 0.5878 - categorical_crossentropy: 2.6111 - val_loss: 2.2042 - val_acc: 0.4672 - val_top_3_accuracy: 0.6821 - val_categorical_crossentropy: 2.2042
# Epoch 7/100
#  - 1089s - loss: 2.4433 - acc: 0.4053 - top_3_accuracy: 0.6219 - categorical_crossentropy: 2.4433 - val_loss: 2.0580 - val_acc: 0.4968 - val_top_3_accuracy: 0.7102 - val_categorical_crossentropy: 2.0580
# Epoch 8/100
#  - 1096s - loss: 2.3212 - acc: 0.4292 - top_3_accuracy: 0.6477 - categorical_crossentropy: 2.3212 - val_loss: 1.9671 - val_acc: 0.5131 - val_top_3_accuracy: 0.7277 - val_categorical_crossentropy: 1.9671
# Epoch 9/100
#  - 1072s - loss: 2.2186 - acc: 0.4490 - top_3_accuracy: 0.6674 - categorical_crossentropy: 2.2186 - val_loss: 1.8943 - val_acc: 0.5274 - val_top_3_accuracy: 0.7393 - val_categorical_crossentropy: 1.8943
# Epoch 10/100
#  - 1090s - loss: 2.1325 - acc: 0.4652 - top_3_accuracy: 0.6845 - categorical_crossentropy: 2.1325 - val_loss: 1.8356 - val_acc: 0.5421 - val_top_3_accuracy: 0.7540 - val_categorical_crossentropy: 1.8356
# Epoch 11/100
#  - 1099s - loss: 2.0590 - acc: 0.4805 - top_3_accuracy: 0.6987 - categorical_crossentropy: 2.0590 - val_loss: 1.7730 - val_acc: 0.5534 - val_top_3_accuracy: 0.7628 - val_categorical_crossentropy: 1.7730
# Epoch 12/100
#  - 1077s - loss: 1.9936 - acc: 0.4932 - top_3_accuracy: 0.7125 - categorical_crossentropy: 1.9936 - val_loss: 1.7308 - val_acc: 0.5624 - val_top_3_accuracy: 0.7708 - val_categorical_crossentropy: 1.7308
# Epoch 13/100
#  - 1090s - loss: 1.9414 - acc: 0.5031 - top_3_accuracy: 0.7215 - categorical_crossentropy: 1.9414 - val_loss: 1.6908 - val_acc: 0.5691 - val_top_3_accuracy: 0.7775 - val_categorical_crossentropy: 1.6908
# Epoch 14/100
#  - 1096s - loss: 1.8867 - acc: 0.5143 - top_3_accuracy: 0.7328 - categorical_crossentropy: 1.8867 - val_loss: 1.6625 - val_acc: 0.5743 - val_top_3_accuracy: 0.7827 - val_categorical_crossentropy: 1.6625
# Epoch 15/100
#  - 1101s - loss: 1.8490 - acc: 0.5228 - top_3_accuracy: 0.7395 - categorical_crossentropy: 1.8490 - val_loss: 1.6263 - val_acc: 0.5838 - val_top_3_accuracy: 0.7883 - val_categorical_crossentropy: 1.6263
# Epoch 16/100
#  - 1113s - loss: 1.8098 - acc: 0.5301 - top_3_accuracy: 0.7469 - categorical_crossentropy: 1.8098 - val_loss: 1.5979 - val_acc: 0.5855 - val_top_3_accuracy: 0.7910 - val_categorical_crossentropy: 1.5979
# Epoch 17/100
#  - 1099s - loss: 1.7728 - acc: 0.5392 - top_3_accuracy: 0.7541 - categorical_crossentropy: 1.7728 - val_loss: 1.5672 - val_acc: 0.5934 - val_top_3_accuracy: 0.7966 - val_categorical_crossentropy: 1.5672
# Epoch 18/100
#  - 1096s - loss: 1.7377 - acc: 0.5458 - top_3_accuracy: 0.7611 - categorical_crossentropy: 1.7377 - val_loss: 1.5511 - val_acc: 0.5966 - val_top_3_accuracy: 0.7991 - val_categorical_crossentropy: 1.5511
# Epoch 19/100
#  - 1091s - loss: 1.7092 - acc: 0.5516 - top_3_accuracy: 0.7662 - categorical_crossentropy: 1.7092 - val_loss: 1.5487 - val_acc: 0.5976 - val_top_3_accuracy: 0.8008 - val_categorical_crossentropy: 1.5487
# Epoch 20/100
#  - 1107s - loss: 1.6803 - acc: 0.5576 - top_3_accuracy: 0.7712 - categorical_crossentropy: 1.6803 - val_loss: 1.5182 - val_acc: 0.6036 - val_top_3_accuracy: 0.8057 - val_categorical_crossentropy: 1.5182
# Epoch 21/100
#  - 1098s - loss: 1.6532 - acc: 0.5625 - top_3_accuracy: 0.7755 - categorical_crossentropy: 1.6532 - val_loss: 1.5012 - val_acc: 0.6058 - val_top_3_accuracy: 0.8067 - val_categorical_crossentropy: 1.5012
# Epoch 22/100
#  - 1104s - loss: 1.6278 - acc: 0.5682 - top_3_accuracy: 0.7810 - categorical_crossentropy: 1.6278 - val_loss: 1.4786 - val_acc: 0.6119 - val_top_3_accuracy: 0.8123 - val_categorical_crossentropy: 1.4786
# Epoch 23/100
#  - 1114s - loss: 1.6085 - acc: 0.5720 - top_3_accuracy: 0.7833 - categorical_crossentropy: 1.6085 - val_loss: 1.5024 - val_acc: 0.6078 - val_top_3_accuracy: 0.8088 - val_categorical_crossentropy: 1.5024
# Epoch 24/100
#  - 1093s - loss: 1.5853 - acc: 0.5772 - top_3_accuracy: 0.7886 - categorical_crossentropy: 1.5853 - val_loss: 1.4724 - val_acc: 0.6121 - val_top_3_accuracy: 0.8133 - val_categorical_crossentropy: 1.4724
# Epoch 25/100
#  - 1113s - loss: 1.5642 - acc: 0.5818 - top_3_accuracy: 0.7925 - categorical_crossentropy: 1.5642 - val_loss: 1.4598 - val_acc: 0.6153 - val_top_3_accuracy: 0.8148 - val_categorical_crossentropy: 1.4598
# Epoch 26/100
#  - 1089s - loss: 1.5487 - acc: 0.5842 - top_3_accuracy: 0.7949 - categorical_crossentropy: 1.5487 - val_loss: 1.4472 - val_acc: 0.6169 - val_top_3_accuracy: 0.8172 - val_categorical_crossentropy: 1.4472
# Epoch 27/100
#  - 1104s - loss: 1.5288 - acc: 0.5885 - top_3_accuracy: 0.7986 - categorical_crossentropy: 1.5288 - val_loss: 1.4370 - val_acc: 0.6193 - val_top_3_accuracy: 0.8178 - val_categorical_crossentropy: 1.4370
# Epoch 28/100
#  - 1097s - loss: 1.5122 - acc: 0.5922 - top_3_accuracy: 0.8017 - categorical_crossentropy: 1.5122 - val_loss: 1.4353 - val_acc: 0.6182 - val_top_3_accuracy: 0.8179 - val_categorical_crossentropy: 1.4353
# Epoch 29/100
#  - 1082s - loss: 1.4996 - acc: 0.5954 - top_3_accuracy: 0.8040 - categorical_crossentropy: 1.4996 - val_loss: 1.4289 - val_acc: 0.6211 - val_top_3_accuracy: 0.8200 - val_categorical_crossentropy: 1.4289
# Epoch 30/100
#  - 1111s - loss: 1.4866 - acc: 0.5984 - top_3_accuracy: 0.8060 - categorical_crossentropy: 1.4866 - val_loss: 1.4178 - val_acc: 0.6230 - val_top_3_accuracy: 0.8214 - val_categorical_crossentropy: 1.4178
# Epoch 31/100
#  - 1080s - loss: 1.4689 - acc: 0.6011 - top_3_accuracy: 0.8096 - categorical_crossentropy: 1.4689 - val_loss: 1.3967 - val_acc: 0.6270 - val_top_3_accuracy: 0.8249 - val_categorical_crossentropy: 1.3967
# Epoch 32/100
#  - 1104s - loss: 1.4576 - acc: 0.6033 - top_3_accuracy: 0.8116 - categorical_crossentropy: 1.4576 - val_loss: 1.4244 - val_acc: 0.6206 - val_top_3_accuracy: 0.8205 - val_categorical_crossentropy: 1.4244
# Epoch 33/100
#  - 1119s - loss: 1.4435 - acc: 0.6067 - top_3_accuracy: 0.8140 - categorical_crossentropy: 1.4435 - val_loss: 1.4064 - val_acc: 0.6252 - val_top_3_accuracy: 0.8228 - val_categorical_crossentropy: 1.4064
# Epoch 34/100
#  - 1087s - loss: 1.4316 - acc: 0.6089 - top_3_accuracy: 0.8158 - categorical_crossentropy: 1.4316 - val_loss: 1.3892 - val_acc: 0.6297 - val_top_3_accuracy: 0.8261 - val_categorical_crossentropy: 1.3892
# Epoch 35/100
#  - 2813s - loss: 1.4217 - acc: 0.6113 - top_3_accuracy: 0.8177 - categorical_crossentropy: 1.4217 - val_loss: 1.3826 - val_acc: 0.6307 - val_top_3_accuracy: 0.8269 - val_categorical_crossentropy: 1.3826
# Epoch 36/100
#  - 1103s - loss: 1.4113 - acc: 0.6131 - top_3_accuracy: 0.8195 - categorical_crossentropy: 1.4113 - val_loss: 1.4007 - val_acc: 0.6259 - val_top_3_accuracy: 0.8234 - val_categorical_crossentropy: 1.4007
# Epoch 37/100
#  - 1165s - loss: 1.3999 - acc: 0.6157 - top_3_accuracy: 0.8215 - categorical_crossentropy: 1.3999 - val_loss: 1.3892 - val_acc: 0.6282 - val_top_3_accuracy: 0.8253 - val_categorical_crossentropy: 1.3892
# Epoch 38/100
#  - 1195s - loss: 1.3907 - acc: 0.6182 - top_3_accuracy: 0.8238 - categorical_crossentropy: 1.3907 - val_loss: 1.3684 - val_acc: 0.6341 - val_top_3_accuracy: 0.8291 - val_categorical_crossentropy: 1.3684
# Epoch 39/100
#  - 1782s - loss: 1.3787 - acc: 0.6206 - top_3_accuracy: 0.8258 - categorical_crossentropy: 1.3787 - val_loss: 1.3722 - val_acc: 0.6316 - val_top_3_accuracy: 0.8289 - val_categorical_crossentropy: 1.3722
# Epoch 40/100
#  - 1309s - loss: 1.3698 - acc: 0.6216 - top_3_accuracy: 0.8271 - categorical_crossentropy: 1.3698 - val_loss: 1.3837 - val_acc: 0.6305 - val_top_3_accuracy: 0.8265 - val_categorical_crossentropy: 1.3837
# Epoch 41/100
#  - 1295s - loss: 1.3628 - acc: 0.6234 - top_3_accuracy: 0.8282 - categorical_crossentropy: 1.3628 - val_loss: 1.3732 - val_acc: 0.6330 - val_top_3_accuracy: 0.8291 - val_categorical_crossentropy: 1.3732
# Epoch 42/100
#  - 1255s - loss: 1.3548 - acc: 0.6250 - top_3_accuracy: 0.8296 - categorical_crossentropy: 1.3548 - val_loss: 1.3796 - val_acc: 0.6319 - val_top_3_accuracy: 0.8271 - val_categorical_crossentropy: 1.3796
# Epoch 43/100
#  - 1211s - loss: 1.3453 - acc: 0.6271 - top_3_accuracy: 0.8313 - categorical_crossentropy: 1.3453 - val_loss: 1.3536 - val_acc: 0.6370 - val_top_3_accuracy: 0.8318 - val_categorical_crossentropy: 1.3536
# Epoch 44/100
#  - 1234s - loss: 1.3412 - acc: 0.6283 - top_3_accuracy: 0.8319 - categorical_crossentropy: 1.3412 - val_loss: 1.3802 - val_acc: 0.6297 - val_top_3_accuracy: 0.8276 - val_categorical_crossentropy: 1.3802
# Epoch 45/100
#  - 1248s - loss: 1.3284 - acc: 0.6312 - top_3_accuracy: 0.8338 - categorical_crossentropy: 1.3284 - val_loss: 1.3761 - val_acc: 0.6308 - val_top_3_accuracy: 0.8281 - val_categorical_crossentropy: 1.3761
# Epoch 46/100
#  - 1305s - loss: 1.3232 - acc: 0.6320 - top_3_accuracy: 0.8352 - categorical_crossentropy: 1.3232 - val_loss: 1.3581 - val_acc: 0.6357 - val_top_3_accuracy: 0.8310 - val_categorical_crossentropy: 1.3581
# Epoch 47/100
#  - 1183s - loss: 1.3188 - acc: 0.6330 - top_3_accuracy: 0.8357 - categorical_crossentropy: 1.3188 - val_loss: 1.3836 - val_acc: 0.6295 - val_top_3_accuracy: 0.8270 - val_categorical_crossentropy: 1.3836
# Epoch 48/100
#  - 1181s - loss: 1.3102 - acc: 0.6356 - top_3_accuracy: 0.8371 - categorical_crossentropy: 1.3102 - val_loss: 1.3886 - val_acc: 0.6275 - val_top_3_accuracy: 0.8268 - val_categorical_crossentropy: 1.3886
# Epoch 49/100
#  - 1163s - loss: 1.3035 - acc: 0.6362 - top_3_accuracy: 0.8384 - categorical_crossentropy: 1.3035 - val_loss: 1.3605 - val_acc: 0.6344 - val_top_3_accuracy: 0.8310 - val_categorical_crossentropy: 1.3605
# Epoch 50/100
#  - 1272s - loss: 1.2991 - acc: 0.6377 - top_3_accuracy: 0.8394 - categorical_crossentropy: 1.2991 - val_loss: 1.3859 - val_acc: 0.6277 - val_top_3_accuracy: 0.8259 - val_categorical_crossentropy: 1.3859
# Epoch 51/100
#  - 1485s - loss: 1.2940 - acc: 0.6384 - top_3_accuracy: 0.8403 - categorical_crossentropy: 1.2940 - val_loss: 1.4064 - val_acc: 0.6218 - val_top_3_accuracy: 0.8228 - val_categorical_crossentropy: 1.4064
# Epoch 52/100
#  - 1556s - loss: 1.2879 - acc: 0.6396 - top_3_accuracy: 0.8412 - categorical_crossentropy: 1.2879 - val_loss: 1.3729 - val_acc: 0.6308 - val_top_3_accuracy: 0.8289 - val_categorical_crossentropy: 1.3729
# Epoch 53/100
#  - 1474s - loss: 1.2814 - acc: 0.6412 - top_3_accuracy: 0.8424 - categorical_crossentropy: 1.2814 - val_loss: 1.3730 - val_acc: 0.6319 - val_top_3_accuracy: 0.8290 - val_categorical_crossentropy: 1.3730
# Epoch 54/100
#  - 1535s - loss: 1.2758 - acc: 0.6424 - top_3_accuracy: 0.8437 - categorical_crossentropy: 1.2758 - val_loss: 1.3530 - val_acc: 0.6371 - val_top_3_accuracy: 0.8320 - val_categorical_crossentropy: 1.3530
# Epoch 55/100
#  - 1522s - loss: 1.2729 - acc: 0.6434 - top_3_accuracy: 0.8440 - categorical_crossentropy: 1.2729 - val_loss: 1.3720 - val_acc: 0.6323 - val_top_3_accuracy: 0.8281 - val_categorical_crossentropy: 1.3720
# Epoch 56/100
#  - 1305s - loss: 1.2705 - acc: 0.6428 - top_3_accuracy: 0.8446 - categorical_crossentropy: 1.2705 - val_loss: 1.3941 - val_acc: 0.6264 - val_top_3_accuracy: 0.8257 - val_categorical_crossentropy: 1.3941
# Epoch 57/100
#  - 1394s - loss: 1.2620 - acc: 0.6448 - top_3_accuracy: 0.8461 - categorical_crossentropy: 1.2620 - val_loss: 1.3605 - val_acc: 0.6339 - val_top_3_accuracy: 0.8314 - val_categorical_crossentropy: 1.3605
# Epoch 58/100
#  - 1919s - loss: 1.2612 - acc: 0.6458 - top_3_accuracy: 0.8456 - categorical_crossentropy: 1.2612 - val_loss: 1.3786 - val_acc: 0.6298 - val_top_3_accuracy: 0.8284 - val_categorical_crossentropy: 1.3786
# Epoch 59/100
#  - 2363s - loss: 1.2535 - acc: 0.6467 - top_3_accuracy: 0.8471 - categorical_crossentropy: 1.2535 - val_loss: 1.3409 - val_acc: 0.6384 - val_top_3_accuracy: 0.8345 - val_categorical_crossentropy: 1.3409
# Epoch 60/100
#  - 1583s - loss: 1.2487 - acc: 0.6480 - top_3_accuracy: 0.8477 - categorical_crossentropy: 1.2487 - val_loss: 1.3912 - val_acc: 0.6258 - val_top_3_accuracy: 0.8253 - val_categorical_crossentropy: 1.3912
# Epoch 61/100
#  - 1259s - loss: 1.2461 - acc: 0.6480 - top_3_accuracy: 0.8484 - categorical_crossentropy: 1.2461 - val_loss: 1.3766 - val_acc: 0.6302 - val_top_3_accuracy: 0.8288 - val_categorical_crossentropy: 1.3766
# Epoch 62/100
#  - 1281s - loss: 1.2434 - acc: 0.6489 - top_3_accuracy: 0.8484 - categorical_crossentropy: 1.2434 - val_loss: 1.3547 - val_acc: 0.6362 - val_top_3_accuracy: 0.8319 - val_categorical_crossentropy: 1.3547
# Epoch 63/100
#  - 1276s - loss: 1.2357 - acc: 0.6509 - top_3_accuracy: 0.8500 - categorical_crossentropy: 1.2357 - val_loss: 1.3822 - val_acc: 0.6290 - val_top_3_accuracy: 0.8271 - val_categorical_crossentropy: 1.3822
# Epoch 64/100
#  - 1236s - loss: 1.2338 - acc: 0.6509 - top_3_accuracy: 0.8508 - categorical_crossentropy: 1.2338 - val_loss: 1.3558 - val_acc: 0.6363 - val_top_3_accuracy: 0.8301 - val_categorical_crossentropy: 1.3558
# Epoch 65/100
#  - 1262s - loss: 1.2320 - acc: 0.6512 - top_3_accuracy: 0.8506 - categorical_crossentropy: 1.2320 - val_loss: 1.3896 - val_acc: 0.6267 - val_top_3_accuracy: 0.8252 - val_categorical_crossentropy: 1.3896
# Epoch 66/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-9b0f6d1d7c69> in <module>()
#       9           epochs=100,
#      10           batch_size=5000,
# ---> 11           verbose=2)
#      12 scores = model.evaluate(X_test, y_test, verbose=0)
#      13 print("CNN Error: %.2f%%" % (100-scores[1]*100))
#
# /usr/local/lib/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# /usr/local/lib/python2.7/site-packages/keras/engine/training_arrays.pyc in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# /usr/local/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in __call__(self, *args, **kwargs)
#    1397           ret = tf_session.TF_SessionRunCallable(
#    1398               self._session._session, self._handle, args, status,
# -> 1399               run_metadata_ptr)
#    1400         if run_metadata:
#    1401           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
# scores = model.evaluate(X_test, y_test, verbose=0)
# print("CNN Error: %.2f%%" % (100-scores[1]*100))
# model
# list all data in history
# from keras.callbacks import History 
# history = History()
# history.History
# print(history.history.keys())

# %%
# Make predictions
preds = model.predict(imgArr_test)
outputDf = test_df.copy()[['key_id']]
outputDf['word'] = ''
map_numeric_to_class_space_normal = map_numeric_to_class.copy()
for key in map_numeric_to_class_space_normal:
    map_numeric_to_class_space_normal[key] = (map_numeric_to_class_space_normal[key].replace(" ", "_"))

for i in tqdm(range(preds.shape[0])):
    outputDf['word'].at[i] = ' '.join(([map_numeric_to_class_space_normal[predClass] for predClass in [tup[1] for tup in sorted(zip(preds[i], range(340)), reverse=True)[:3]]]))

# Create csv
outputDf.to_csv('initial_pred.csv', index=False)
# Out:
# 100%|██████████| 112199/112199 [00:21<00:00, 5140.20it/s]

# %%
# Save the model
# serialize model to JSON
model_json = model.to_json()
with open(("Saved_Models/model_" + str(datetime.today())[:16].replace(" ", "_").replace(":","-") + ".json"), "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights(("Saved_Models/model_" + str(datetime.today())[:16].replace(" ", "_").replace(":","-") + ".h5"))
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# Load the model back
# load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")
 
# evaluate loaded model on test data
loaded_model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
score = loaded_model.evaluate(X, Y, verbose=0)
print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))
