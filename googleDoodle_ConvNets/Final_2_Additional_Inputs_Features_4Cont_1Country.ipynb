# %%
import random
import os
import re
from glob import glob
from tqdm import tqdm
import numpy as np

import pandas as pd
import ast
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from PIL import Image, ImageDraw, _imaging
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Input, Dense, Dropout, Flatten, Activation, Embedding
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.merge import concatenate
from keras.utils import plot_model
from keras.models import Model
from keras import backend as K
from keras import metrics
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
from sklearn.model_selection import train_test_split
import tensorflow as tf
from datetime import datetime
from keras.callbacks import History, ModelCheckpoint
history = History()
from keras.models import model_from_json
import graphviz
# Out:
# Using TensorFlow backend.
# <style>.container { width:100% !important; }</style>

# %%
random.seed(111)

# Generate class mappings
fnames = glob('train_simplified/*.csv')
tempDf = pd.DataFrame(columns=pd.read_csv(fnames[0], nrows=1).columns)

for name in fnames:
    data = pd.read_csv(name, nrows=2)
    tempDf = tempDf.append(data)
    
ys = tempDf['word']
    
# Convert class labels from categorical to numerical
unique_classes_list = ys.unique()
map_class_to_numeric = {k: v for v, k in enumerate(unique_classes_list)}
map_numeric_to_class = {v: k for k, v in map_class_to_numeric.iteritems()}

countryList = '''['BD','BE','BF','BG','BA','NotAvlbl','BM','BN','BO','JP','BI','BJ','BT','JM','JO','WS','BR','CR','JE','BY','BZ','RU','RW','BB','RS','TL','RE','TM','LR','RO','GU','GT','GR','GP','BH','GY','GG','GF','GE','GD','GB','GA','GN','GM','GL','GI','GH','OM','TN','BU','BW','HR','BS','HT','HU','HK','HN','AD','PR','PS','PW','PT','KN','PY','AI','PA','PF','PG','PE','PK','PH','PL','PM','ZM','EE','EG','ZA','EC','AL','AO','ZZ','ET','ZW','KY','ES','ME','MD','MG','MF','MA','MC','UZ','MM','ML','MO','MN','MH','US','MU','MT','MW','MV','MQ','MP','MS','MR','IM','UG','TZ','MY','MX','IL','FR','SJ','FI','FJ','FM','FO','NI','NL','NO','SO','VU','NC','NF','NG','NZ','NP','CI','CH','CO','CN','CM','CL','CA','CG','CF','OTHER','CD','CZ','CY','CX','UY','CW','CV','SZ','SX','KG','KE','SS','SR','KH','SV','ST','SK','KR','SI','KW','SN','SM','SC','KZ','SA','SG','SE','DO','DM','DJ','DK','VG','DE','YE','DZ','MK','YT','LB','LC','LA','TW','TT','TR','LK','LI','LV','TO','LT','LU','TJ','LS','TH','TG','TC','LY','VC','AE','VE','AG','AF','IQ','VI','IS','IR','AM','IT','VN','AN','AS','AR','AU','AT','AW','IN','AX','AZ','IE','ID','UA','QA','MZ']'''
countryList = eval(countryList)
countryIntMap = {value: int_value+1 for int_value, value in enumerate(countryList)}

# Functions to create other features
def numNonZero(imgArr):
    return np.argwhere(imgArr > 0).shape[0]

def numPointsInStrokes(drawing):
    points = 0
    for strokes in drawing:
        points += len(strokes[0])
    return points

def numPointsInBiggestStroke(drawing):
    maxPoints = 0
    for strokes in drawing:
        if len(strokes[0]) > maxPoints:
            maxPoints = len(strokes[0])
    return maxPoints

def draw_it(raw_strokes, output_height, output_width):
#     raw_strokes = eval(raw_strokes)
    image = Image.new("P", (255,255)
#                       , color=1
            )
    image_draw = ImageDraw.Draw(image)

    for stroke in raw_strokes:
        for i in range(len(stroke[0])-1):

            image_draw.line([stroke[0][i], 
                             stroke[1][i],
                             stroke[0][i+1], 
                             stroke[1][i+1]],
                            fill=255, width=6)
    # Reduce image size
    image = image.resize((output_height,output_width),Image.ANTIALIAS)
    
    return np.array(image)

# %%
def showSampleImgs():
    n_samp = 3
    train_df_sample = train_df.sample(n_samp)
    plt.figure(figsize=(4,4))
    for i in range(n_samp):
        draw = train_df_sample.iloc[i]['drawing']
        label = train_df_sample.iloc[i]['word']
        plt.subplot(n_samp,1,i+1)
        for stroke in draw:
            plt.plot(stroke[0], stroke[1], marker='.', color='black')
            plt.title(label)
            plt.axis('off')
    plt.show()    
    
# Show an image from the dataframe
def showImgFromDf(df, index):
    # Show an image
    plt.imshow(df.iloc[index]['img'],cmap='gray')
    plt.title(df.iloc[index]['word'])
    plt.show()
    
def top_3_accuracy(y_true, y_pred):
    return metrics.top_k_categorical_accuracy(y_true, y_pred, k=3)

def baseline_conv_model_functional_API(num_filters, num_classes, img_height, img_width):
    # Input Layer
    inputLayerImg = Input(shape=(img_height,img_width,1))
    
    conv1 = Conv2D(num_filters*1, (5,5), activation='relu')(inputLayerImg)
    pool1 = MaxPooling2D(pool_size=(2,2))(conv1)
    dropout1 = Dropout(0.2)(pool1)
    
    conv2 = Conv2D(num_filters*2, (5,5), activation='relu')(dropout1)
    pool2 = MaxPooling2D(pool_size=(2,2))(conv2)
    dropout2 = Dropout(0.2)(pool2)
    
    conv3 = Conv2D(num_filters*4, (3,3), activation='relu')(dropout2)
    dropout3 = Dropout(0.2)(conv3)
    
    flat = Flatten()(dropout3)
    
    # Add the other scalar inputs as another data stream
    # Continuous variables
    inputLayerScalars = Input(shape=(4,))
    
    # Categorical variables
    # Define the embedding input
    inputLayer_Country = Input(shape=(1,)) 
    countryEmbeddingsLength = 15
#     # Let’s define the embedding layer and flatten it
    countryEmbeddings = Embedding(input_dim=(len(countryList)+1), output_dim=countryEmbeddingsLength, input_length=1)(inputLayer_Country)
    countryEmbeddings = keras.layers.Reshape((countryEmbeddingsLength,))(countryEmbeddings)
    
    # Merge the CNN flat layer and the other input layer
    mergedInput = concatenate([flat, inputLayerScalars, countryEmbeddings])
    
    dense1 = Dense(2000, activation='relu')(mergedInput)
    drop_dense1 = Dropout(0.2)(dense1)
    
    dense2 = Dense(1500, activation='relu')(drop_dense1)
    drop_dense2 = Dropout(0.2)(dense2)
    
    dense3 = Dense(1000, activation='relu')(drop_dense2)
    drop_dense3 = Dropout(0.2)(dense3)
    
    outputLayer = Dense(num_classes, activation=tf.nn.softmax)(drop_dense3)
    
    model = Model(inputs=[inputLayerImg, inputLayerScalars, inputLayer_Country], outputs=outputLayer)
    
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', top_3_accuracy, 'categorical_crossentropy'])
    return model

# %%
# model = baseline_conv_model_functional_API(numStartFilters, numClasses, img_height, img_width)
# from IPython.display import SVG
# from keras.utils.vis_utils import model_to_dot

# SVG(model_to_dot(model).create(prog='dot', format='svg'))

# %%
class DataGenerator(keras.utils.Sequence):
    def __init__(self, num_samples_to_train, batch_size, trainGeneratorDataOffsetPerClass, img_width, img_height):
        self.batch_size = batch_size
        self.num_samples_to_train = num_samples_to_train
        self.img_width = img_width
        self.img_height = img_height
        self.trainGeneratorDataOffsetPerClass = trainGeneratorDataOffsetPerClass
    
    def __len__(self):
        return np.ceil(self.num_samples_to_train / float(self.batch_size))
    
    def __getitem__(self, idx):
        
        numRowsEachDf = int(self.batch_size / float(numClasses))
        skipRows = (idx * numRowsEachDf) + self.trainGeneratorDataOffsetPerClass
        img_height = self.img_height 
        img_width = self.img_width
        
        X, y = DataGenerator._getNextData(numRowsEachDf, skipRows, img_height, img_width)
        
        return X, y
    
    @staticmethod
    def _getNextData(numRowsEachDf, skipRows, img_height, img_width):
        
        fnames = glob('train_simplified/*.csv')
        numClasses = len(fnames)

        # Get n rows from all the csv files and append them into one dataframe
        train_df = pd.DataFrame(columns=pd.read_csv(fnames[0], nrows=1).columns)
        
        for name in fnames:
            if skipRows == 0:
                data = pd.read_csv(name, nrows=numRowsEachDf)
            else:
                data = pd.read_csv(name, nrows=numRowsEachDf, skiprows=range(1,skipRows)) # 0th row is the header, so not skipping that
            # Append the training data of all the classes
            train_df = train_df.append(data)
            
        train_df = train_df.reset_index().drop('index', axis=1)
        
        # Some data manipulations
        train_df['countrycode'] = train_df['countrycode'].fillna('NotAvlbl')

        # Shuffle all data points
        train_df = train_df.sample(train_df.shape[0])

        # Get only those which were correctly recognized
        train_df = train_df[train_df['recognized'] == True]

        # Apply eval to drawing object
        train_df['drawing'] = train_df['drawing'].apply(eval)
        
        # Other features from the drawing array
        numStrokes_ = train_df['drawing'].apply(len)
        numPointsInBiggestStroke_ = train_df['drawing'].apply(numPointsInBiggestStroke)
        numPointsInStrokes_ = train_df['drawing'].apply(numPointsInStrokes)

        
        # Convert drawing to images
        train_df['drawing'] = train_df['drawing'].apply(lambda x: draw_it(x, img_height, img_width))
        
        # Features from the constructed image
        num_non_zero_image_cells_ = train_df['drawing'].apply(numNonZero)

        # Reshape the array
        train_imgArr = np.vstack(train_df['drawing'].values).flatten().reshape((train_df['drawing'].shape[0], img_height, img_width))
    
        # In Keras, the layers used for two-dimensional convolutions expect pixel values with the dimensions [width][height][pixels] for TF.
        # In the case of RGB, the first dimension pixels would be 3 for the red, green and blue components and it would be like having 3 image inputs for every color image. In this case, the pixel values are gray scale, the pixel dimension is set to 1.
        train_X = train_imgArr.reshape(train_imgArr.shape[0], img_height, img_width, 1).astype('float32')
        
        
         # Initialize the y_train
        y_train = train_df['word']
    
        y_train_numeric = y_train.apply(lambda x: map_class_to_numeric[x])

        # convert class vectors to binary class matrices
        train_y = keras.utils.to_categorical(y_train_numeric, numClasses)
    
        # Get other features
        # Continuous
        # Convert continuous variables into numpy array for ingestion [TODO: normalize]
        train_X_scalars = np.array(pd.concat([numStrokes_,numPointsInBiggestStroke_, numPointsInStrokes_, num_non_zero_image_cells_], axis=1)).astype('float32')
        
        # Discrete
        train_X_countryInt = np.array(train_df['countrycode'].map(countryIntMap)).astype('int32')
        
        return [train_X, train_X_scalars, train_X_countryInt], train_y

# %%
img_width = img_height = 32

# %%
X_test, y_test = DataGenerator._getNextData(100, 90000, img_height, img_width)

# %%
# pp = []
batch_size = 1000
numTrainExamplesPerClass = 500
numClasses = 340
num_samples_to_train = (numTrainExamplesPerClass*numClasses)
trainGeneratorDataOffsetPerClass = 0
dataGenerator = DataGenerator(num_samples_to_train, batch_size, trainGeneratorDataOffsetPerClass, img_width, img_height)

# %%
# ############## Remove
# img_width = img_height = 32
# numClasses = 340
# numStartFilters = 8
# model = baseline_conv_model_functional_API(numStartFilters, numClasses, img_height, img_width)
# ############## Remove
# model.summary()

# %%
# model = baseline_conv_model(4, 340, 32, 32)
numStartFilters = 8
model = baseline_conv_model_functional_API(numStartFilters, numClasses, img_height, img_width)
model.fit_generator(
        generator=dataGenerator,
        epochs=100,
        verbose=1,
        shuffle=False,
        validation_data=(X_test, y_test)
    
#         ,
#         use_multiprocessing=True,
)
#       steps_per_epoch=(num_training_samples // batch_size),
#       validation_data=my_validation_batch_generator,
#       validation_steps=(num_validation_samples // batch_size),
#       use_multiprocessing=False,
#       workers=16,
#       max_queue_size=32)
# Out:
# Epoch 1/100
# 170/170 [==============================] - 1568s 9s/step - loss: 5.7914 - acc: 0.0258 - top_3_accuracy: 0.0637 - categorical_crossentropy: 5.7914 - val_loss: 4.4898 - val_acc: 0.0870 - val_top_3_accuracy: 0.1912 - val_categorical_crossentropy: 4.4898
# Epoch 2/100
# 170/170 [==============================] - 1412s 8s/step - loss: 4.2882 - acc: 0.1074 - top_3_accuracy: 0.2226 - categorical_crossentropy: 4.2882 - val_loss: 3.9001 - val_acc: 0.1649 - val_top_3_accuracy: 0.3126 - val_categorical_crossentropy: 3.9001
# Epoch 3/100
# 170/170 [==============================] - 1404s 8s/step - loss: 3.8372 - acc: 0.1660 - top_3_accuracy: 0.3179 - categorical_crossentropy: 3.8372 - val_loss: 3.4447 - val_acc: 0.2321 - val_top_3_accuracy: 0.4094 - val_categorical_crossentropy: 3.4447
# Epoch 4/100
# 170/170 [==============================] - 1256s 7s/step - loss: 3.5373 - acc: 0.2073 - top_3_accuracy: 0.3824 - categorical_crossentropy: 3.5373 - val_loss: 3.2202 - val_acc: 0.2727 - val_top_3_accuracy: 0.4650 - val_categorical_crossentropy: 3.2202
# Epoch 5/100
# 170/170 [==============================] - 1266s 7s/step - loss: 3.3063 - acc: 0.2433 - top_3_accuracy: 0.4326 - categorical_crossentropy: 3.3063 - val_loss: 3.0024 - val_acc: 0.3036 - val_top_3_accuracy: 0.5053 - val_categorical_crossentropy: 3.0024
# Epoch 6/100
# 170/170 [==============================] - 1248s 7s/step - loss: 3.1408 - acc: 0.2695 - top_3_accuracy: 0.4667 - categorical_crossentropy: 3.1408 - val_loss: 2.8362 - val_acc: 0.3358 - val_top_3_accuracy: 0.5434 - val_categorical_crossentropy: 2.8362
# Epoch 7/100
# 170/170 [==============================] - 1241s 7s/step - loss: 3.0048 - acc: 0.2906 - top_3_accuracy: 0.4950 - categorical_crossentropy: 3.0048 - val_loss: 2.7212 - val_acc: 0.3541 - val_top_3_accuracy: 0.5682 - val_categorical_crossentropy: 2.7212
# Epoch 8/100
# 170/170 [==============================] - 1245s 7s/step - loss: 2.8952 - acc: 0.3089 - top_3_accuracy: 0.5182 - categorical_crossentropy: 2.8952 - val_loss: 2.6725 - val_acc: 0.3625 - val_top_3_accuracy: 0.5743 - val_categorical_crossentropy: 2.6725
# Epoch 9/100
# 170/170 [==============================] - 1235s 7s/step - loss: 2.8045 - acc: 0.3238 - top_3_accuracy: 0.5361 - categorical_crossentropy: 2.8045 - val_loss: 2.5546 - val_acc: 0.3801 - val_top_3_accuracy: 0.5991 - val_categorical_crossentropy: 2.5546
# Epoch 10/100
# 170/170 [==============================] - 1375s 8s/step - loss: 2.7212 - acc: 0.3380 - top_3_accuracy: 0.5550 - categorical_crossentropy: 2.7212 - val_loss: 2.5119 - val_acc: 0.3871 - val_top_3_accuracy: 0.6062 - val_categorical_crossentropy: 2.5119
# Epoch 11/100
# 170/170 [==============================] - 1391s 8s/step - loss: 2.6488 - acc: 0.3508 - top_3_accuracy: 0.5694 - categorical_crossentropy: 2.6488 - val_loss: 2.4494 - val_acc: 0.3991 - val_top_3_accuracy: 0.6200 - val_categorical_crossentropy: 2.4494
# Epoch 12/100
# 170/170 [==============================] - 1273s 7s/step - loss: 2.5893 - acc: 0.3627 - top_3_accuracy: 0.5812 - categorical_crossentropy: 2.5893 - val_loss: 2.4185 - val_acc: 0.4055 - val_top_3_accuracy: 0.6243 - val_categorical_crossentropy: 2.4185
# Epoch 13/100
# 170/170 [==============================] - 1254s 7s/step - loss: 2.5350 - acc: 0.3696 - top_3_accuracy: 0.5913 - categorical_crossentropy: 2.5350 - val_loss: 2.3695 - val_acc: 0.4141 - val_top_3_accuracy: 0.6375 - val_categorical_crossentropy: 2.3695
# Epoch 14/100
# 170/170 [==============================] - 1300s 8s/step - loss: 2.4804 - acc: 0.3801 - top_3_accuracy: 0.6038 - categorical_crossentropy: 2.4804 - val_loss: 2.3368 - val_acc: 0.4233 - val_top_3_accuracy: 0.6420 - val_categorical_crossentropy: 2.3368
# Epoch 15/100
# 170/170 [==============================] - 1265s 7s/step - loss: 2.4292 - acc: 0.3885 - top_3_accuracy: 0.6119 - categorical_crossentropy: 2.4292 - val_loss: 2.3273 - val_acc: 0.4244 - val_top_3_accuracy: 0.6449 - val_categorical_crossentropy: 2.3273
# Epoch 16/100
# 170/170 [==============================] - 1254s 7s/step - loss: 2.3881 - acc: 0.3970 - top_3_accuracy: 0.6200 - categorical_crossentropy: 2.3881 - val_loss: 2.2954 - val_acc: 0.4302 - val_top_3_accuracy: 0.6515 - val_categorical_crossentropy: 2.2954
# Epoch 17/100
# 170/170 [==============================] - 1261s 7s/step - loss: 2.3496 - acc: 0.4010 - top_3_accuracy: 0.6277 - categorical_crossentropy: 2.3496 - val_loss: 2.2774 - val_acc: 0.4350 - val_top_3_accuracy: 0.6558 - val_categorical_crossentropy: 2.2774
# Epoch 18/100
# 170/170 [==============================] - 1277s 8s/step - loss: 2.3123 - acc: 0.4086 - top_3_accuracy: 0.6369 - categorical_crossentropy: 2.3123 - val_loss: 2.2871 - val_acc: 0.4338 - val_top_3_accuracy: 0.6551 - val_categorical_crossentropy: 2.2871
# Epoch 19/100
# 170/170 [==============================] - 1244s 7s/step - loss: 2.2856 - acc: 0.4138 - top_3_accuracy: 0.6414 - categorical_crossentropy: 2.2856 - val_loss: 2.2741 - val_acc: 0.4341 - val_top_3_accuracy: 0.6573 - val_categorical_crossentropy: 2.2741
# Epoch 20/100
# 170/170 [==============================] - 1279s 8s/step - loss: 2.2469 - acc: 0.4205 - top_3_accuracy: 0.6493 - categorical_crossentropy: 2.2469 - val_loss: 2.2582 - val_acc: 0.4396 - val_top_3_accuracy: 0.6610 - val_categorical_crossentropy: 2.2582
# Epoch 21/100
# 170/170 [==============================] - 1264s 7s/step - loss: 2.2190 - acc: 0.4252 - top_3_accuracy: 0.6552 - categorical_crossentropy: 2.2190 - val_loss: 2.2455 - val_acc: 0.4419 - val_top_3_accuracy: 0.6634 - val_categorical_crossentropy: 2.2455
# Epoch 22/100
# 170/170 [==============================] - 1258s 7s/step - loss: 2.1987 - acc: 0.4291 - top_3_accuracy: 0.6584 - categorical_crossentropy: 2.1987 - val_loss: 2.2459 - val_acc: 0.4431 - val_top_3_accuracy: 0.6643 - val_categorical_crossentropy: 2.2459
# Epoch 23/100
# 170/170 [==============================] - 1272s 7s/step - loss: 2.1696 - acc: 0.4346 - top_3_accuracy: 0.6649 - categorical_crossentropy: 2.1696 - val_loss: 2.2368 - val_acc: 0.4475 - val_top_3_accuracy: 0.6677 - val_categorical_crossentropy: 2.2368
# Epoch 24/100
# 170/170 [==============================] - 1294s 8s/step - loss: 2.1413 - acc: 0.4403 - top_3_accuracy: 0.6708 - categorical_crossentropy: 2.1413 - val_loss: 2.2263 - val_acc: 0.4489 - val_top_3_accuracy: 0.6667 - val_categorical_crossentropy: 2.2263
# Epoch 25/100
# 170/170 [==============================] - 1311s 8s/step - loss: 2.1224 - acc: 0.4411 - top_3_accuracy: 0.6737 - categorical_crossentropy: 2.1224 - val_loss: 2.2636 - val_acc: 0.4420 - val_top_3_accuracy: 0.6596 - val_categorical_crossentropy: 2.2636
# Epoch 26/100
# 170/170 [==============================] - 1271s 7s/step - loss: 2.0999 - acc: 0.4470 - top_3_accuracy: 0.6797 - categorical_crossentropy: 2.0999 - val_loss: 2.2503 - val_acc: 0.4455 - val_top_3_accuracy: 0.6649 - val_categorical_crossentropy: 2.2503
# Epoch 27/100
# 170/170 [==============================] - 1270s 7s/step - loss: 2.0909 - acc: 0.4488 - top_3_accuracy: 0.6817 - categorical_crossentropy: 2.0909 - val_loss: 2.2332 - val_acc: 0.4495 - val_top_3_accuracy: 0.6678 - val_categorical_crossentropy: 2.2332
# Epoch 28/100
# 170/170 [==============================] - 1289s 8s/step - loss: 2.0614 - acc: 0.4547 - top_3_accuracy: 0.6877 - categorical_crossentropy: 2.0614 - val_loss: 2.2502 - val_acc: 0.4474 - val_top_3_accuracy: 0.6662 - val_categorical_crossentropy: 2.2502
# Epoch 29/100
# 170/170 [==============================] - 1256s 7s/step - loss: 2.0375 - acc: 0.4577 - top_3_accuracy: 0.6925 - categorical_crossentropy: 2.0375 - val_loss: 2.2430 - val_acc: 0.4490 - val_top_3_accuracy: 0.6671 - val_categorical_crossentropy: 2.2430
# Epoch 30/100
# 170/170 [==============================] - 1254s 7s/step - loss: 2.0244 - acc: 0.4561 - top_3_accuracy: 0.6950 - categorical_crossentropy: 2.0244 - val_loss: 2.2485 - val_acc: 0.4505 - val_top_3_accuracy: 0.6690 - val_categorical_crossentropy: 2.2485
# Epoch 31/100
# 170/170 [==============================] - 1233s 7s/step - loss: 1.9966 - acc: 0.4663 - top_3_accuracy: 0.6989 - categorical_crossentropy: 1.9966 - val_loss: 2.2610 - val_acc: 0.4475 - val_top_3_accuracy: 0.6648 - val_categorical_crossentropy: 2.2610
# Epoch 32/100
# 170/170 [==============================] - 1244s 7s/step - loss: 1.9860 - acc: 0.4687 - top_3_accuracy: 0.7013 - categorical_crossentropy: 1.9860 - val_loss: 2.2608 - val_acc: 0.4495 - val_top_3_accuracy: 0.6676 - val_categorical_crossentropy: 2.2608
# Epoch 33/100
# 170/170 [==============================] - 1228s 7s/step - loss: 1.9758 - acc: 0.4700 - top_3_accuracy: 0.7053 - categorical_crossentropy: 1.9758 - val_loss: 2.2801 - val_acc: 0.4479 - val_top_3_accuracy: 0.6650 - val_categorical_crossentropy: 2.2801
# Epoch 34/100
# 170/170 [==============================] - 1263s 7s/step - loss: 1.9601 - acc: 0.4726 - top_3_accuracy: 0.7076 - categorical_crossentropy: 1.9601 - val_loss: 2.2436 - val_acc: 0.4568 - val_top_3_accuracy: 0.6710 - val_categorical_crossentropy: 2.2436
# Epoch 35/100
# 170/170 [==============================] - 1230s 7s/step - loss: 1.9481 - acc: 0.4740 - top_3_accuracy: 0.7096 - categorical_crossentropy: 1.9481 - val_loss: 2.2900 - val_acc: 0.4436 - val_top_3_accuracy: 0.6620 - val_categorical_crossentropy: 2.2900
# Epoch 36/100
# 170/170 [==============================] - 1271s 7s/step - loss: 1.9308 - acc: 0.4765 - top_3_accuracy: 0.7142 - categorical_crossentropy: 1.9308 - val_loss: 2.2714 - val_acc: 0.4519 - val_top_3_accuracy: 0.6679 - val_categorical_crossentropy: 2.2714
# Epoch 37/100
# 170/170 [==============================] - 1246s 7s/step - loss: 1.9010 - acc: 0.4849 - top_3_accuracy: 0.7212 - categorical_crossentropy: 1.9010 - val_loss: 2.2799 - val_acc: 0.4498 - val_top_3_accuracy: 0.6680 - val_categorical_crossentropy: 2.2799
# Epoch 38/100
# 170/170 [==============================] - 1259s 7s/step - loss: 1.8953 - acc: 0.4853 - top_3_accuracy: 0.7201 - categorical_crossentropy: 1.8953 - val_loss: 2.2938 - val_acc: 0.4489 - val_top_3_accuracy: 0.6676 - val_categorical_crossentropy: 2.2938
# Epoch 39/100
# 170/170 [==============================] - 1288s 8s/step - loss: 1.8798 - acc: 0.4881 - top_3_accuracy: 0.7243 - categorical_crossentropy: 1.8798 - val_loss: 2.3409 - val_acc: 0.4397 - val_top_3_accuracy: 0.6561 - val_categorical_crossentropy: 2.3409
# Epoch 40/100
# 170/170 [==============================] - 1258s 7s/step - loss: 1.8750 - acc: 0.4904 - top_3_accuracy: 0.7245 - categorical_crossentropy: 1.8750 - val_loss: 2.2715 - val_acc: 0.4545 - val_top_3_accuracy: 0.6690 - val_categorical_crossentropy: 2.2715
# Epoch 41/100
# 170/170 [==============================] - 1240s 7s/step - loss: 1.8533 - acc: 0.4917 - top_3_accuracy: 0.7286 - categorical_crossentropy: 1.8533 - val_loss: 2.2988 - val_acc: 0.4492 - val_top_3_accuracy: 0.6629 - val_categorical_crossentropy: 2.2988
# Epoch 42/100
# 170/170 [==============================] - 3491s 21s/step - loss: 1.8263 - acc: 0.4991 - top_3_accuracy: 0.7335 - categorical_crossentropy: 1.8263 - val_loss: 2.3031 - val_acc: 0.4505 - val_top_3_accuracy: 0.6658 - val_categorical_crossentropy: 2.3031
# Epoch 43/100
# 170/170 [==============================] - 1396s 8s/step - loss: 1.8171 - acc: 0.5010 - top_3_accuracy: 0.7389 - categorical_crossentropy: 1.8171 - val_loss: 2.2984 - val_acc: 0.4528 - val_top_3_accuracy: 0.6654 - val_categorical_crossentropy: 2.2984
# Epoch 44/100
# 170/170 [==============================] - 1218s 7s/step - loss: 1.8053 - acc: 0.5040 - top_3_accuracy: 0.7400 - categorical_crossentropy: 1.8053 - val_loss: 2.3175 - val_acc: 0.4464 - val_top_3_accuracy: 0.6642 - val_categorical_crossentropy: 2.3175
# Epoch 45/100
# 170/170 [==============================] - 1217s 7s/step - loss: 1.7955 - acc: 0.5060 - top_3_accuracy: 0.7414 - categorical_crossentropy: 1.7955 - val_loss: 2.3051 - val_acc: 0.4520 - val_top_3_accuracy: 0.6655 - val_categorical_crossentropy: 2.3051
# Epoch 46/100
# 170/170 [==============================] - 988s 6s/step - loss: 1.7731 - acc: 0.5104 - top_3_accuracy: 0.7459 - categorical_crossentropy: 1.7731 - val_loss: 2.3214 - val_acc: 0.4478 - val_top_3_accuracy: 0.6651 - val_categorical_crossentropy: 2.3214
# Epoch 47/100
# 170/170 [==============================] - 810s 5s/step - loss: 1.7677 - acc: 0.5103 - top_3_accuracy: 0.7475 - categorical_crossentropy: 1.7677 - val_loss: 2.3271 - val_acc: 0.4520 - val_top_3_accuracy: 0.6621 - val_categorical_crossentropy: 2.3271
# Epoch 48/100
# 170/170 [==============================] - 622s 4s/step - loss: 1.7564 - acc: 0.5129 - top_3_accuracy: 0.7499 - categorical_crossentropy: 1.7564 - val_loss: 2.3309 - val_acc: 0.4490 - val_top_3_accuracy: 0.6642 - val_categorical_crossentropy: 2.3309
# Epoch 49/100
# 170/170 [==============================] - 629s 4s/step - loss: 1.7465 - acc: 0.5137 - top_3_accuracy: 0.7516 - categorical_crossentropy: 1.7465 - val_loss: 2.3551 - val_acc: 0.4485 - val_top_3_accuracy: 0.6619 - val_categorical_crossentropy: 2.3551
# Epoch 50/100
# 170/170 [==============================] - 605s 4s/step - loss: 1.7325 - acc: 0.5184 - top_3_accuracy: 0.7540 - categorical_crossentropy: 1.7325 - val_loss: 2.3710 - val_acc: 0.4433 - val_top_3_accuracy: 0.6572 - val_categorical_crossentropy: 2.3710
# Epoch 51/100
# 170/170 [==============================] - 627s 4s/step - loss: 1.7350 - acc: 0.5164 - top_3_accuracy: 0.7548 - categorical_crossentropy: 1.7350 - val_loss: 2.3716 - val_acc: 0.4456 - val_top_3_accuracy: 0.6592 - val_categorical_crossentropy: 2.3716
# Epoch 52/100
# 170/170 [==============================] - 585s 3s/step - loss: 1.7156 - acc: 0.5225 - top_3_accuracy: 0.7589 - categorical_crossentropy: 1.7156 - val_loss: 2.3571 - val_acc: 0.4495 - val_top_3_accuracy: 0.6625 - val_categorical_crossentropy: 2.3571
# Epoch 53/100
# 170/170 [==============================] - 566s 3s/step - loss: 1.7119 - acc: 0.5240 - top_3_accuracy: 0.7586 - categorical_crossentropy: 1.7119 - val_loss: 2.4011 - val_acc: 0.4426 - val_top_3_accuracy: 0.6591 - val_categorical_crossentropy: 2.4011
# Epoch 54/100
# 170/170 [==============================] - 522s 3s/step - loss: 1.7241 - acc: 0.5225 - top_3_accuracy: 0.7575 - categorical_crossentropy: 1.7241 - val_loss: 2.3773 - val_acc: 0.4443 - val_top_3_accuracy: 0.6579 - val_categorical_crossentropy: 2.3773
# Epoch 55/100
# 170/170 [==============================] - 444s 3s/step - loss: 1.7116 - acc: 0.5256 - top_3_accuracy: 0.7608 - categorical_crossentropy: 1.7116 - val_loss: 2.3933 - val_acc: 0.4441 - val_top_3_accuracy: 0.6600 - val_categorical_crossentropy: 2.3933
# Epoch 56/100
# 170/170 [==============================] - 419s 2s/step - loss: 1.6849 - acc: 0.5296 - top_3_accuracy: 0.7644 - categorical_crossentropy: 1.6849 - val_loss: 2.4119 - val_acc: 0.4432 - val_top_3_accuracy: 0.6593 - val_categorical_crossentropy: 2.4119
# Epoch 57/100
# 170/170 [==============================] - 380s 2s/step - loss: 1.6774 - acc: 0.5324 - top_3_accuracy: 0.7674 - categorical_crossentropy: 1.6774 - val_loss: 2.3933 - val_acc: 0.4478 - val_top_3_accuracy: 0.6638 - val_categorical_crossentropy: 2.3933
# Epoch 58/100
# 170/170 [==============================] - 400s 2s/step - loss: 1.6494 - acc: 0.5362 - top_3_accuracy: 0.7719 - categorical_crossentropy: 1.6494 - val_loss: 2.3883 - val_acc: 0.4469 - val_top_3_accuracy: 0.6629 - val_categorical_crossentropy: 2.3883
# Epoch 59/100
# 170/170 [==============================] - 390s 2s/step - loss: 1.6516 - acc: 0.5365 - top_3_accuracy: 0.7724 - categorical_crossentropy: 1.6516 - val_loss: 2.4260 - val_acc: 0.4470 - val_top_3_accuracy: 0.6580 - val_categorical_crossentropy: 2.4260
# Epoch 60/100
# 170/170 [==============================] - 420s 2s/step - loss: 1.6492 - acc: 0.5377 - top_3_accuracy: 0.7728 - categorical_crossentropy: 1.6492 - val_loss: 2.4099 - val_acc: 0.4456 - val_top_3_accuracy: 0.6584 - val_categorical_crossentropy: 2.4099
# Epoch 61/100
# 170/170 [==============================] - 411s 2s/step - loss: 1.6288 - acc: 0.5409 - top_3_accuracy: 0.7755 - categorical_crossentropy: 1.6288 - val_loss: 2.4262 - val_acc: 0.4442 - val_top_3_accuracy: 0.6561 - val_categorical_crossentropy: 2.4262
# Epoch 62/100
# 170/170 [==============================] - 461s 3s/step - loss: 1.6290 - acc: 0.5420 - top_3_accuracy: 0.7766 - categorical_crossentropy: 1.6290 - val_loss: 2.4406 - val_acc: 0.4422 - val_top_3_accuracy: 0.6568 - val_categorical_crossentropy: 2.4406
# Epoch 63/100
# 170/170 [==============================] - 436s 3s/step - loss: 1.6304 - acc: 0.5418 - top_3_accuracy: 0.7759 - categorical_crossentropy: 1.6304 - val_loss: 2.4295 - val_acc: 0.4433 - val_top_3_accuracy: 0.6573 - val_categorical_crossentropy: 2.4295
# Epoch 64/100
# 170/170 [==============================] - 409s 2s/step - loss: 1.6180 - acc: 0.5448 - top_3_accuracy: 0.7773 - categorical_crossentropy: 1.6180 - val_loss: 2.4449 - val_acc: 0.4457 - val_top_3_accuracy: 0.6587 - val_categorical_crossentropy: 2.4449
# Epoch 65/100
# 170/170 [==============================] - 490s 3s/step - loss: 1.6008 - acc: 0.5504 - top_3_accuracy: 0.7826 - categorical_crossentropy: 1.6008 - val_loss: 2.4398 - val_acc: 0.4442 - val_top_3_accuracy: 0.6543 - val_categorical_crossentropy: 2.4398
# Epoch 66/100
# 170/170 [==============================] - 405s 2s/step - loss: 1.5963 - acc: 0.5497 - top_3_accuracy: 0.7825 - categorical_crossentropy: 1.5963 - val_loss: 2.4862 - val_acc: 0.4405 - val_top_3_accuracy: 0.6545 - val_categorical_crossentropy: 2.4862
# Epoch 67/100
# 170/170 [==============================] - 407s 2s/step - loss: 1.5904 - acc: 0.5507 - top_3_accuracy: 0.7846 - categorical_crossentropy: 1.5904 - val_loss: 2.4548 - val_acc: 0.4440 - val_top_3_accuracy: 0.6567 - val_categorical_crossentropy: 2.4548
# Epoch 68/100
# 170/170 [==============================] - 426s 3s/step - loss: 1.5819 - acc: 0.5531 - top_3_accuracy: 0.7860 - categorical_crossentropy: 1.5819 - val_loss: 2.4341 - val_acc: 0.4424 - val_top_3_accuracy: 0.6590 - val_categorical_crossentropy: 2.4341
# Epoch 69/100
# 170/170 [==============================] - 412s 2s/step - loss: 1.5796 - acc: 0.5529 - top_3_accuracy: 0.7880 - categorical_crossentropy: 1.5796 - val_loss: 2.4698 - val_acc: 0.4448 - val_top_3_accuracy: 0.6556 - val_categorical_crossentropy: 2.4698
# Epoch 70/100
# 170/170 [==============================] - 483s 3s/step - loss: 1.5952 - acc: 0.5499 - top_3_accuracy: 0.7836 - categorical_crossentropy: 1.5952 - val_loss: 2.4714 - val_acc: 0.4433 - val_top_3_accuracy: 0.6558 - val_categorical_crossentropy: 2.4714
# Epoch 71/100
# 170/170 [==============================] - 423s 2s/step - loss: 1.5760 - acc: 0.5544 - top_3_accuracy: 0.7881 - categorical_crossentropy: 1.5760 - val_loss: 2.4616 - val_acc: 0.4396 - val_top_3_accuracy: 0.6527 - val_categorical_crossentropy: 2.4616
# Epoch 72/100
# 170/170 [==============================] - 403s 2s/step - loss: 1.5607 - acc: 0.5590 - top_3_accuracy: 0.7901 - categorical_crossentropy: 1.5607 - val_loss: 2.4828 - val_acc: 0.4406 - val_top_3_accuracy: 0.6543 - val_categorical_crossentropy: 2.4828
# Epoch 73/100
# 170/170 [==============================] - 406s 2s/step - loss: 1.5501 - acc: 0.5607 - top_3_accuracy: 0.7931 - categorical_crossentropy: 1.5501 - val_loss: 2.5047 - val_acc: 0.4396 - val_top_3_accuracy: 0.6513 - val_categorical_crossentropy: 2.5047
# Epoch 74/100
# 170/170 [==============================] - 427s 3s/step - loss: 1.5511 - acc: 0.5607 - top_3_accuracy: 0.7922 - categorical_crossentropy: 1.5511 - val_loss: 2.5350 - val_acc: 0.4360 - val_top_3_accuracy: 0.6486 - val_categorical_crossentropy: 2.5350
# Epoch 75/100
# 170/170 [==============================] - 458s 3s/step - loss: 1.5494 - acc: 0.5605 - top_3_accuracy: 0.7928 - categorical_crossentropy: 1.5494 - val_loss: 2.5714 - val_acc: 0.4328 - val_top_3_accuracy: 0.6416 - val_categorical_crossentropy: 2.5714
# Epoch 76/100
# 170/170 [==============================] - 427s 3s/step - loss: 1.5541 - acc: 0.5599 - top_3_accuracy: 0.7927 - categorical_crossentropy: 1.5541 - val_loss: 2.5440 - val_acc: 0.4314 - val_top_3_accuracy: 0.6459 - val_categorical_crossentropy: 2.5440
# Epoch 77/100
# 170/170 [==============================] - 417s 2s/step - loss: 1.5393 - acc: 0.5652 - top_3_accuracy: 0.7955 - categorical_crossentropy: 1.5393 - val_loss: 2.5446 - val_acc: 0.4331 - val_top_3_accuracy: 0.6458 - val_categorical_crossentropy: 2.5446
# Epoch 78/100
# 170/170 [==============================] - 417s 2s/step - loss: 1.5557 - acc: 0.5594 - top_3_accuracy: 0.7930 - categorical_crossentropy: 1.5557 - val_loss: 2.5943 - val_acc: 0.4244 - val_top_3_accuracy: 0.6345 - val_categorical_crossentropy: 2.5943
# Epoch 79/100
# 170/170 [==============================] - 430s 3s/step - loss: 1.5423 - acc: 0.5631 - top_3_accuracy: 0.7959 - categorical_crossentropy: 1.5423 - val_loss: 2.5791 - val_acc: 0.4320 - val_top_3_accuracy: 0.6421 - val_categorical_crossentropy: 2.5791
# Epoch 80/100
# 170/170 [==============================] - 444s 3s/step - loss: 1.5242 - acc: 0.5661 - top_3_accuracy: 0.7978 - categorical_crossentropy: 1.5242 - val_loss: 2.5861 - val_acc: 0.4295 - val_top_3_accuracy: 0.6407 - val_categorical_crossentropy: 2.5861
# Epoch 81/100
# 170/170 [==============================] - 421s 2s/step - loss: 1.5156 - acc: 0.5676 - top_3_accuracy: 0.8005 - categorical_crossentropy: 1.5156 - val_loss: 2.5807 - val_acc: 0.4318 - val_top_3_accuracy: 0.6442 - val_categorical_crossentropy: 2.5807
# Epoch 82/100
# 170/170 [==============================] - 435s 3s/step - loss: 1.5061 - acc: 0.5721 - top_3_accuracy: 0.8019 - categorical_crossentropy: 1.5061 - val_loss: 2.5800 - val_acc: 0.4296 - val_top_3_accuracy: 0.6410 - val_categorical_crossentropy: 2.5800
# Epoch 83/100
# 170/170 [==============================] - 425s 3s/step - loss: 1.5050 - acc: 0.5709 - top_3_accuracy: 0.8023 - categorical_crossentropy: 1.5050 - val_loss: 2.6133 - val_acc: 0.4239 - val_top_3_accuracy: 0.6360 - val_categorical_crossentropy: 2.6133
# Epoch 84/100
# 170/170 [==============================] - 424s 2s/step - loss: 1.4951 - acc: 0.5739 - top_3_accuracy: 0.8039 - categorical_crossentropy: 1.4951 - val_loss: 2.5735 - val_acc: 0.4358 - val_top_3_accuracy: 0.6458 - val_categorical_crossentropy: 2.5735
# Epoch 85/100
# 170/170 [==============================] - 420s 2s/step - loss: 1.4875 - acc: 0.5769 - top_3_accuracy: 0.8066 - categorical_crossentropy: 1.4875 - val_loss: 2.5579 - val_acc: 0.4314 - val_top_3_accuracy: 0.6470 - val_categorical_crossentropy: 2.5579
# Epoch 86/100
# 170/170 [==============================] - 414s 2s/step - loss: 1.4769 - acc: 0.5784 - top_3_accuracy: 0.8076 - categorical_crossentropy: 1.4769 - val_loss: 2.6053 - val_acc: 0.4294 - val_top_3_accuracy: 0.6395 - val_categorical_crossentropy: 2.6053
# Epoch 87/100
# 170/170 [==============================] - 410s 2s/step - loss: 1.4653 - acc: 0.5830 - top_3_accuracy: 0.8106 - categorical_crossentropy: 1.4653 - val_loss: 2.5797 - val_acc: 0.4354 - val_top_3_accuracy: 0.6459 - val_categorical_crossentropy: 2.5797
# Epoch 88/100
# 170/170 [==============================] - 417s 2s/step - loss: 1.4513 - acc: 0.5826 - top_3_accuracy: 0.8118 - categorical_crossentropy: 1.4513 - val_loss: 2.5806 - val_acc: 0.4356 - val_top_3_accuracy: 0.6475 - val_categorical_crossentropy: 2.5806
# Epoch 89/100
# 170/170 [==============================] - 424s 2s/step - loss: 1.4501 - acc: 0.5840 - top_3_accuracy: 0.8128 - categorical_crossentropy: 1.4501 - val_loss: 2.6382 - val_acc: 0.4305 - val_top_3_accuracy: 0.6431 - val_categorical_crossentropy: 2.6382
# Epoch 90/100
# 170/170 [==============================] - 379s 2s/step - loss: 1.4614 - acc: 0.5834 - top_3_accuracy: 0.8118 - categorical_crossentropy: 1.4614 - val_loss: 2.6014 - val_acc: 0.4336 - val_top_3_accuracy: 0.6448 - val_categorical_crossentropy: 2.6014
# Epoch 91/100
# 170/170 [==============================] - 412s 2s/step - loss: 1.4598 - acc: 0.5829 - top_3_accuracy: 0.8124 - categorical_crossentropy: 1.4598 - val_loss: 2.6658 - val_acc: 0.4287 - val_top_3_accuracy: 0.6368 - val_categorical_crossentropy: 2.6658
# Epoch 92/100
# 170/170 [==============================] - 421s 2s/step - loss: 1.4606 - acc: 0.5818 - top_3_accuracy: 0.8128 - categorical_crossentropy: 1.4606 - val_loss: 2.6258 - val_acc: 0.4295 - val_top_3_accuracy: 0.6357 - val_categorical_crossentropy: 2.6258
# Epoch 93/100
# 170/170 [==============================] - 399s 2s/step - loss: 1.4533 - acc: 0.5843 - top_3_accuracy: 0.8130 - categorical_crossentropy: 1.4533 - val_loss: 2.6536 - val_acc: 0.4297 - val_top_3_accuracy: 0.6377 - val_categorical_crossentropy: 2.6536
# Epoch 94/100
# 170/170 [==============================] - 456s 3s/step - loss: 1.4383 - acc: 0.5876 - top_3_accuracy: 0.8158 - categorical_crossentropy: 1.4383 - val_loss: 2.6544 - val_acc: 0.4252 - val_top_3_accuracy: 0.6355 - val_categorical_crossentropy: 2.6544
# Epoch 95/100
# 170/170 [==============================] - 3796s 22s/step - loss: 1.4549 - acc: 0.5849 - top_3_accuracy: 0.8121 - categorical_crossentropy: 1.4549 - val_loss: 2.6471 - val_acc: 0.4299 - val_top_3_accuracy: 0.6390 - val_categorical_crossentropy: 2.6471
# Epoch 96/100
# 170/170 [==============================] - 380s 2s/step - loss: 1.4387 - acc: 0.5894 - top_3_accuracy: 0.8158 - categorical_crossentropy: 1.4387 - val_loss: 2.6744 - val_acc: 0.4245 - val_top_3_accuracy: 0.6366 - val_categorical_crossentropy: 2.6744
# Epoch 97/100
# 170/170 [==============================] - 389s 2s/step - loss: 1.4454 - acc: 0.5869 - top_3_accuracy: 0.8149 - categorical_crossentropy: 1.4454 - val_loss: 2.6371 - val_acc: 0.4317 - val_top_3_accuracy: 0.6418 - val_categorical_crossentropy: 2.6371
# Epoch 98/100
# 170/170 [==============================] - 387s 2s/step - loss: 1.4401 - acc: 0.5879 - top_3_accuracy: 0.8153 - categorical_crossentropy: 1.4401 - val_loss: 2.6591 - val_acc: 0.4320 - val_top_3_accuracy: 0.6409 - val_categorical_crossentropy: 2.6591
# Epoch 99/100
# 170/170 [==============================] - 394s 2s/step - loss: 1.4303 - acc: 0.5897 - top_3_accuracy: 0.8179 - categorical_crossentropy: 1.4303 - val_loss: 2.6473 - val_acc: 0.4310 - val_top_3_accuracy: 0.6408 - val_categorical_crossentropy: 2.6473
# Epoch 100/100
# 170/170 [==============================] - 379s 2s/step - loss: 1.4265 - acc: 0.5922 - top_3_accuracy: 0.8191 - categorical_crossentropy: 1.4265 - val_loss: 2.6742 - val_acc: 0.4271 - val_top_3_accuracy: 0.6392 - val_categorical_crossentropy: 2.6742

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("CNN Error: %.2f%%" % (100-scores[1]*100))
# model
# Out:
# CNN Error: 29.11%

# %%
# model = 0

# %%
# %%time
# # Transform data for CNN
# X_train, X_test, y_train, y_test, imgArr_test, map_class_to_numeric, map_numeric_to_class = CNN_dataPrep(train_df, img_height, img_width)

# %%
# num_filters = 2
# num_classes = 340
# continueTrain = False
# if continueTrain == False:
#     model = baseline_conv_model(num_filters, num_classes, img_height, img_width)

# # checkpoint
# filepath="Saved_Models/weights.best.hdf5"
# checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
# callbacks = [checkpoint]

# print(model.summary())

# hist = model.fit(X_train, 
#           y_train, 
#           validation_data=(X_test, y_test),
#           epochs=2, 
#           batch_size=5, 
#           verbose=2,
#           callbacks = callbacks)

# %%
# Save the model
# serialize model to JSON
model_json = model.to_json()
with open(("Saved_Models/model_" + str(datetime.today())[:16].replace(" ", "_").replace(":","-") + ".json"), "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights(("Saved_Models/model_" + str(datetime.today())[:16].replace(" ", "_").replace(":","-") + ".h5"))
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# model = ""

# %%
# Load the model back
# load json and create model
json_file = open('Saved_Models/model_2018-11-21_02-44.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("Saved_Models/model_2018-11-21_02-44.h5")
print("Loaded model from disk")
 
# evaluate loaded model on test data
loaded_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', top_3_accuracy, 'categorical_crossentropy'])
# score = loaded_model.evaluate(X, Y, verbose=0)
# print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))
model = loaded_model
# Out:
# Loaded model from disk

# %% [markdown]
# # Create Test Data Set

# %%
def getTestData(img_height, img_width):
        
        numClasses = 340

        test_df = pd.read_csv('test_simplified.csv')            

        # Convert drawing to images
        test_df['drawing'] = test_df['drawing'].apply(lambda x: draw_it(x, img_height, img_width))

        # Reshape the array
        test_imgArr = np.vstack(test_df['drawing'].values).flatten().reshape((test_df['drawing'].shape[0], img_height, img_width))
    
        # In Keras, the layers used for two-dimensional convolutions expect pixel values with the dimensions [width][height][pixels] for TF.
        # In the case of RGB, the first dimension pixels would be 3 for the red, green and blue components and it would be like having 3 image inputs for every color image. In this case, the pixel values are gray scale, the pixel dimension is set to 1.
        test_X = test_imgArr.reshape(test_imgArr.shape[0], img_height, img_width, 1).astype('float32')
                
        return test_df, test_X

# %%
test_df, test_X = getTestData(img_width, img_height)

# %%
# Make predictions
preds = model.predict(test_X)
outputDf = test_df.copy()[['key_id']]
outputDf['word'] = ''
map_numeric_to_class_space_normal = map_numeric_to_class.copy()
for key in map_numeric_to_class_space_normal:
    map_numeric_to_class_space_normal[key] = (map_numeric_to_class_space_normal[key].replace(" ", "_"))

for i in tqdm(range(preds.shape[0])):
    outputDf['word'].at[i] = ' '.join(([map_numeric_to_class_space_normal[predClass] for predClass in [tup[1] for tup in sorted(zip(preds[i], range(340)), reverse=True)[:3]]]))

# Create csv
outputDf.to_csv('initial_pred.csv', index=False)
# Out:
# 100%|██████████| 112199/112199 [00:22<00:00, 5018.47it/s]
